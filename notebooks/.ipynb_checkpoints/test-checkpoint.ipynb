# %%
# add modules folder to Python's search path
from os import times
import sys
from pathlib import Path
from os.path import dirname, realpath, abspath
script_dir = Path(abspath(''))#Path(dirname(realpath(__file__)))
module_dir = str(script_dir.parent)
sys.path.insert(0, module_dir + '/modules')
sys.path.insert(0, module_dir + '/equations')
print(module_dir)
#print(script_dir)
import cv2
from matplotlib import pyplot as plt
import numpy as np
import ensemble
import circle as eqn

img_path = '../assets/paraboloid.png'
record_path = '../data'
ens = ensemble.Ensemble(img_path, record_path)
ens.get_dark_pixels(threshold=180)
d = ens.particles
sde = eqn.get_sde()
print(ens.particles)
ens.move(sde, 200.0, 1e-1)
# Out:
# C:\Users\pinak\Documents\Github\ito-art
# [[ 1.10909091e-01 -1.02702703e-01]
#  [ 1.12727273e-01 -1.02702703e-01]
#  [ 1.09090909e-01 -1.04504505e-01]
#  ...
#  [ 1.81818182e-03 -9.44144144e-01]
#  [-1.73767451e-16 -9.45945946e-01]
#  [-1.74098437e-16 -9.47747748e-01]]
# Time taken by evolve is 2.0098135471343994 seconds

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(d[:, 0], d[:, 1], s=0.01)
ax.set_aspect(1)
plt.show()

# %%
print(d.shape)
# Out:
# (11957, 2)

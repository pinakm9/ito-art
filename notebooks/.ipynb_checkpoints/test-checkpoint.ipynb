# %%
# add modules folder to Python's search path
from os import times
import sys
from pathlib import Path
from os.path import dirname, realpath, abspath
script_dir = Path(abspath(''))#Path(dirname(realpath(__file__)))
module_dir = str(script_dir.parent)
sys.path.insert(0, module_dir + '/modules')
sys.path.insert(0, module_dir + '/equations')
print(module_dir)
#print(script_dir)
import cv2
from matplotlib import pyplot as plt
import numpy as np
import ensemble
import circle as eqn

img_path = '../assets/paraboloid.png'
record_path = '../data'
sde, specs = eqn.get_sde()
ens = ensemble.Ensemble(img_path, record_path, sde)
ens.get_dark_pixels(threshold=180)
d = ens.particles
print(ens.particles)
ens.move(specs)
# Out:
# C:\Users\pinak\Documents\Github\ito-art
# C:\Users\pinak\Documents\GitHub
# [[ 0.69818182 -0.52072072]
#  [ 0.53636364 -0.85945946]
#  [ 0.36       -0.72972973]
#  ...
#  [ 0.11454545 -0.12792793]
#  [ 0.20181818 -0.67027027]
#  [ 0.06181818 -0.85765766]]
# Time taken by evolve is 1.204477071762085 seconds

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(d[:, 0], d[:, 1], s=1, c=ens.colors)
ax.set_aspect(1)
plt.show()

# %%
ens.animate(24*6)
# Out:
# Frame 50 has been drawn.

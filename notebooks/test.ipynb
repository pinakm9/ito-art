# %%
# add modules folder to Python's search path
from os import times
import sys
from pathlib import Path
from os.path import dirname, realpath, abspath
script_dir = Path(abspath(''))#Path(dirname(realpath(__file__)))
module_dir = str(script_dir.parent)
sys.path.insert(0, module_dir + '/modules')
sys.path.insert(0, module_dir + '/equations')
print(module_dir)
#print(script_dir)
import cv2
from matplotlib import pyplot as plt
import numpy as np
import ensemble
import circle as eqn

img_path = '../assets/hbt.png'
record_path = '../data'
sde, specs = eqn.get_sde()
ens = ensemble.Ensemble(img_path, record_path, sde)
ens.get_dark_pixels(threshold=180)
d = ens.particles
print(ens.particles)
ens.move(specs)
# Out:
# C:\Users\pinak\Documents\GitHub\ito-art
# C:\Users\pinak\Documents\GitHub
# [[ 0.23146293 -0.40031153]
#  [ 0.3987976  -0.25700935]
#  [ 0.69038076 -0.46261682]
#  ...
#  [ 0.54509018 -0.22741433]
#  [ 0.31162325 -0.20249221]
#  [ 0.70140281 -0.42367601]]
# Time taken by evolve is 0.9649960994720459 seconds

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(d[:, 0], d[:, 1], s=1, c=ens.colors)
ax.set_aspect(1)
plt.show()

# %%
ens.animate(24*6)
# Out:
# Time taken by animate is 267.2406041622162 seconds
